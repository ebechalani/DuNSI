# %% [markdown]
# # Chiffre de César
#
# **À écrire :** la transformation d'une lettre.

# %%
def cesar(texte, decalage):
    res = ""
    for c in texte:
        if c.isalpha():
            # TODO — décaler la lettre c :
            #   1. base = ord('A') si c est majuscule, sinon ord('a')
            #   2. ajouter à res : chr((ord(c) - base + decalage) % 26 + base)
            pass
        else:
            res += c
    return res

print(cesar("BONJOUR", 3))    # ERQMRXU
print(cesar("ERQMRXU", -3))   # BONJOUR
