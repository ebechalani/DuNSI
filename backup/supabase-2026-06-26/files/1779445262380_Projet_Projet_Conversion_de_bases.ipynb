# %% [markdown]
# # Conversion de bases
#
# **À écrire :** la boucle de conversion décimal -> binaire.

# %%
def decimal_vers_binaire(n):
    if n == 0:
        return "0"
    bits = ""
    # TODO — divisions successives par 2 :
    #   tant que n > 0 :
    #     1. ajouter le reste (n % 2) DEVANT bits  ->  bits = str(n % 2) + bits
    #     2. n = n // 2
    pass
    return bits

print(decimal_vers_binaire(13))   # 1101
print(decimal_vers_binaire(42))   # 101010
