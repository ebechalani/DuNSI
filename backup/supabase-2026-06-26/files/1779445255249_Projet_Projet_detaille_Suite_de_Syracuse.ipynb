# %% [markdown]
# # Suite de Syracuse
#
# **À écrire :** le cœur de la boucle (l'évolution de `n`).

# %%
def syracuse(n):
    vol = [n]
    while n != 1:
        # TODO — faire évoluer n selon sa parité :
        #   1. si n est PAIR (n % 2 == 0) -> n devient n // 2
        #   2. sinon (impair)             -> n devient 3 * n + 1
        pass
        vol.append(n)
    return vol

vol = syracuse(27)
print("Temps de vol :", len(vol) - 1)   # attendu 111
print("Altitude max :", max(vol))        # attendu 9232
