# %% [markdown]
# # Le Pendu
#
# **À écrire :** la réaction à la lettre proposée.

# %%
import random

mot = random.choice(["python", "ordinateur", "variable", "boucle"])
trouvees = set()
essais = 6

while essais > 0:
    affichage = "".join(c if c in trouvees else "_" for c in mot)
    print(affichage, "  essais :", essais)
    if "_" not in affichage:
        print("Gagné !"); break
    lettre = input("Lettre : ").lower()
    # TODO :
    #   1. si la lettre est dans le mot -> l'ajouter à l'ensemble trouvees
    #   2. sinon -> perdre un essai (essais -= 1)
    pass
else:
    print("Perdu ! Le mot était :", mot)
