# %% [markdown]
# # Chiffre de Vigenère
#
# **À écrire :** le décalage variable donné par la clé.

# %%
def vigenere(texte, cle, sens=1):
    res = ""
    j = 0
    for c in texte:
        if c.isalpha():
            # TODO :
            #   1. d = (ord(cle[j % len(cle)].lower()) - ord('a')) * sens   # décalage de la clé
            #   2. base = ord('A') si majuscule, sinon ord('a')
            #   3. ajouter chr((ord(c) - base + d) % 26 + base) à res
            #   4. j += 1   (on n'avance dans la clé que sur les lettres)
            pass
        else:
            res += c
    return res

ch = vigenere("BONJOUR", "CLE")
print(ch)
print(vigenere(ch, "CLE", -1))   # déchiffrement
