# %% [markdown]
# # Recherche dichotomique
#
# **À écrire :** le corps de la boucle (la comparaison au milieu).

# %%
def dichotomie(L, v):
    gauche, droite = 0, len(L) - 1
    while gauche <= droite:
        # TODO :
        #   1. milieu = (gauche + droite) // 2
        #   2. si L[milieu] == v -> renvoyer milieu
        #   3. si L[milieu] < v  -> chercher à droite : gauche = milieu + 1
        #   4. sinon             -> chercher à gauche : droite = milieu - 1
        pass
    return -1

print(dichotomie([1, 2, 3, 5, 8, 9, 12], 8))   # attendu 4
