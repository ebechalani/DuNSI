# %% [markdown]
# # Jeu de la vie de Conway
#
# **À écrire :** le comptage des voisines vivantes.

# %%
def voisins(grille, i, j):
    n = 0
    # TODO — parcourir les 8 voisines :
    #   pour di dans (-1,0,1) et dj dans (-1,0,1), en excluant (0,0) :
    #     soit x, y = i+di, j+dj
    #     si (x, y) est dans la grille : ajouter grille[x][y] à n
    return n

g = [[0, 0, 0],
     [1, 1, 1],
     [0, 0, 0]]
print(voisins(g, 0, 1))   # 3
