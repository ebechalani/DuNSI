# %% [markdown]
# # Puissance 4 (version console)
#
# **À écrire :** la pose du jeton et le test horizontal.

# %%
import numpy as np
LIGNES, COLONNES = 6, 7

def nouvelle_grille():
    return np.zeros((LIGNES, COLONNES), dtype=int)

def jouer(grille, col, joueur):
    # TODO — faire tomber le jeton :
    #   parcourir les lignes du BAS vers le haut (range(LIGNES-1, -1, -1))
    #   à la première case vide (== 0) : y mettre joueur et renvoyer la ligne
    #   si la colonne est pleine, renvoyer -1
    pass

def gagne(grille, joueur):
    # TODO — alignement HORIZONTAL de 4 :
    #   pour chaque ligne i et chaque départ j (0..COLONNES-4) :
    #     si np.all(grille[i, j:j+4] == joueur) -> renvoyer True
    #   (verticales et diagonales : voir la fiche)
    return False

g = nouvelle_grille()
for j in range(4):
    jouer(g, j, 1)
print(gagne(g, 1))   # True une fois jouer() et gagne() complétés
