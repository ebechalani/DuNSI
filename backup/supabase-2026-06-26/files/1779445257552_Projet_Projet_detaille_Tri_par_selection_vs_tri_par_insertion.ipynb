# %% [markdown]
# # Tri par sélection vs tri par insertion
#
# **À écrire :** le cœur de chaque tri.

# %%
def tri_selection(L):
    L = L.copy()
    for i in range(len(L) - 1):
        # TODO — placer le minimum de L[i:] en position i :
        #   1. idx_min = i
        #   2. pour j de i+1 à len(L)-1 : si L[j] < L[idx_min], idx_min = j
        #   3. échanger L[i] et L[idx_min]
        pass
    return L

def tri_insertion(L):
    L = L.copy()
    for i in range(1, len(L)):
        cle = L[i]
        j = i - 1
        # TODO — insérer cle dans la partie triée L[0..i-1] :
        #   1. tant que j >= 0 ET L[j] > cle : décaler L[j] vers la droite (L[j+1] = L[j]) puis j -= 1
        #   2. placer cle en L[j+1]
        pass
    return L

print(tri_selection([5, 2, 8, 1, 9, 3]))
print(tri_insertion([5, 2, 8, 1, 9, 3]))
