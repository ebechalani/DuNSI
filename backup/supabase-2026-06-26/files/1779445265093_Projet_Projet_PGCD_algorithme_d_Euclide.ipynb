# %% [markdown]
# # PGCD (algorithme d'Euclide)
#
# **À écrire :** la boucle d'Euclide.

# %%
def pgcd(a, b):
    # TODO — algorithme d'Euclide :
    #   tant que b != 0 : remplacer (a, b) par (b, a % b)
    #   puis renvoyer a
    pass

print(pgcd(36, 24))     # 12
print(pgcd(1071, 462))  # 21
