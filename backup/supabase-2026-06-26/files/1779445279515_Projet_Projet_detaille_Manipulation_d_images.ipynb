# %% [markdown]
# # Manipulation d'images
#
# **À écrire :** le négatif et le seuillage (numpy).

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.tile(np.linspace(0, 255, 100, dtype=int), (100, 1))

# TODO :
#   1. negatif = inverse chaque pixel  ->  255 - image
#   2. seuil   = binarisation          ->  np.where(image > 128, 255, 0)
negatif = image      # à remplacer
seuil = image        # à remplacer

fig, ax = plt.subplots(1, 3)
ax[0].imshow(image, cmap='gray');   ax[0].set_title('original')
ax[1].imshow(negatif, cmap='gray'); ax[1].set_title('négatif')
ax[2].imshow(seuil, cmap='gray');   ax[2].set_title('seuil')
plt.show()
