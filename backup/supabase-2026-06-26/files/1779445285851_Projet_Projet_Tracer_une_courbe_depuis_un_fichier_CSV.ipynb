# %% [markdown]
# # Tracer une courbe depuis un CSV
#
# **À écrire :** la lecture des deux colonnes.

# %%
import csv
import matplotlib.pyplot as plt

with open('data.csv', 'w', encoding='utf-8') as f:
    f.write("1,0\n2,3\n3,5\n5,9\n6,10\n7,11\n8,15\n9,16")

xs, ys = [], []
with open('data.csv', newline='', encoding='utf-8') as f:
    for ligne in csv.reader(f):
        # TODO — chaque 'ligne' est une liste ['x', 'y'] (du texte) :
        #   1. convertir ligne[0] en float et l'ajouter à xs
        #   2. convertir ligne[1] en float et l'ajouter à ys
        pass

plt.plot(xs, ys, marker='o')
plt.grid(True)
plt.show()
