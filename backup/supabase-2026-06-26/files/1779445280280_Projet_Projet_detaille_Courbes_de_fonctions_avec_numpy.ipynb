# %% [markdown]
# # Courbes de fonctions avec numpy
#
# **À écrire :** le tracé des deux courbes.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 300)

# TODO — tracer deux courbes avec un label chacune :
#   1. la parabole x**2          -> plt.plot(x, x**2, label='x²')
#   2. le sinus np.sin(x)        -> plt.plot(x, np.sin(x), label='sin(x)')

plt.legend()
plt.grid(True)
plt.show()
