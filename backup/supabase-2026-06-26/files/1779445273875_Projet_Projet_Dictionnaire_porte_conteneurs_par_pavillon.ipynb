# %% [markdown]
# # Porte-conteneurs par pavillon
#
# **À écrire :** les deux fonctions du module.

# %%
PorteConteneurs = [["Panama", "Liberia", "Allemagne"], [663, 477, 273]]
Tonnage         = [["Allemagne", "Liberia", "Panama"], [11646, 16521, 23282]]

def listeToDict(liste):
    # TODO — transformer [[clés], [valeurs]] en dictionnaire {clé: valeur}
    #   (boucle sur les indices, ou dict(zip(liste[0], liste[1])))
    pass

def tonnage_moyen_pour_un_pays(dt, dp):
    moyennes = {}
    # TODO — pour chaque pays présent dans dt ET dp (et dp[pays] != 0) :
    #   moyennes[pays] = round(dt[pays] / dp[pays], 2)
    return moyennes

dp = listeToDict(PorteConteneurs)
dt = listeToDict(Tonnage)
print(tonnage_moyen_pour_un_pays(dt, dp))
