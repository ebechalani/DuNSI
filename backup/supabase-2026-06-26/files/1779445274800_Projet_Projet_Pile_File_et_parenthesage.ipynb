# %% [markdown]
# # Pile, File et parenthésage
#
# **À écrire :** la vérification avec une pile.

# %%
def equilibre(expr):
    pile = []
    paires = {")": "(", "]": "[", "}": "{"}
    for c in expr:
        # TODO :
        #   1. si c est une ouvrante ( ( [ { ) -> l'empiler (pile.append(c))
        #   2. si c est une fermante ( ) ] } ) ->
        #        si la pile est vide OU pile.pop() != paires[c] : renvoyer False
        pass
    # TODO — à la fin, l'expression est correcte si la pile est VIDE -> renvoyer len(pile) == 0
    return False

print(equilibre("(a[b]{c})"))   # True
print(equilibre("(a[b)"))       # False
