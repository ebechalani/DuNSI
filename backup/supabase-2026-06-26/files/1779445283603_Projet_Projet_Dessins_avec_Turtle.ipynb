# %% [markdown]
# # Dessins avec Turtle
#
# **À écrire :** le tracé d'un polygone régulier. (Turtle = Python installé, pas Basthon.)

# %%
import turtle
t = turtle.Turtle()
t.speed(0)

def polygone(t, n, cote):
    # TODO — répéter n fois :
    #   1. avancer de 'cote'  (t.forward(cote))
    #   2. tourner de 360 / n degrés  (t.left(360 / n))
    pass

polygone(t, 6, 80)   # hexagone
turtle.done()
