# %% [markdown]
# # Dictionnaire : comptage de mots
#
# **À écrire :** le comptage.

# %%
import string

texte = "Le chat dort. Le chien dort aussi. Le chat mange."
texte = texte.lower()
for signe in string.punctuation:
    texte = texte.replace(signe, " ")

compte = {}
for mot in texte.split():
    # TODO — incrémenter le compteur du mot :
    #   compte[mot] = (valeur actuelle, ou 0 si absent) + 1   -> utilise compte.get(mot, 0)
    pass

for mot, n in compte.items():
    print(mot, ':', n)
