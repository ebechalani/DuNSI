# %% [markdown]
# # Mastermind
#
# **À écrire :** le calcul des indices.

# %%
import random

def mastermind():
    code = [random.randint(1, 6) for _ in range(4)]
    for tour in range(10):
        prop = [int(c) for c in input("4 chiffres (1-6) : ")]
        # TODO :
        #   1. bien = nombre de positions i où prop[i] == code[i]
        #   2. communs = somme sur chaque chiffre d de min(prop.count(d), code.count(d))
        #   3. mal = communs - bien
        bien, mal = 0, 0
        print(bien, "bien placés,", mal, "mal placés")
        if bien == 4:
            print("Gagné !"); return
    print("Code :", code)

mastermind()
