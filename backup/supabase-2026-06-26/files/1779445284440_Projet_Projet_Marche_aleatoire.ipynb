# %% [markdown]
# # Marche aléatoire
#
# **À écrire :** le déplacement à chaque pas.

# %%
import random
import matplotlib.pyplot as plt

x, y = 0, 0
xs, ys = [x], [y]
for _ in range(1000):
    # TODO :
    #   1. tirer un déplacement : dx, dy = random.choice([(1,0),(-1,0),(0,1),(0,-1)])
    #   2. mettre à jour x et y (x += dx ; y += dy)
    #   3. ajouter x à xs et y à ys
    pass

plt.plot(xs, ys)
plt.axis('equal')
plt.show()
