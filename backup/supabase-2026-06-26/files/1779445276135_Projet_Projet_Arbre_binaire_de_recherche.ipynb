# %% [markdown]
# # Arbre binaire de recherche
#
# **À écrire :** l'insertion et le parcours infixe.

# %%
class Noeud:
    def __init__(self, v):
        self.v = v
        self.g = None
        self.d = None

def inserer(racine, v):
    if racine is None:
        return Noeud(v)
    # TODO :
    #   si v < racine.v -> racine.g = inserer(racine.g, v)   (à gauche)
    #   sinon           -> racine.d = inserer(racine.d, v)   (à droite)
    return racine

def infixe(racine):
    # TODO — parcours gauche, nœud, droite :
    #   si racine n'est pas None : infixe(racine.g) ; print(racine.v, end=' ') ; infixe(racine.d)
    pass

racine = None
for v in [5, 3, 8, 1, 4, 7]:
    racine = inserer(racine, v)
infixe(racine)   # 1 3 4 5 7 8
