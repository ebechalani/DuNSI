# %% [markdown]
# # Droite de régression linéaire
#
# **À écrire :** l'ajustement et le tracé de la droite.

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.array([1, 2, 3, 4, 5])
ys = np.array([2.1, 3.9, 6.2, 7.8, 10.1])

# TODO :
#   1. a, b = np.polyfit(xs, ys, 1)      # pente et ordonnée à l'origine
#   2. tracer le nuage : plt.scatter(xs, ys)
#   3. tracer la droite : plt.plot(xs, a * xs + b, 'r')

plt.show()
