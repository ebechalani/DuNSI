# %% [markdown]
# # Approximation de π (Monte-Carlo)
#
# **À écrire :** le tirage et le test.

# %%
import random

def estimer_pi(n):
    dedans = 0
    for _ in range(n):
        # TODO :
        #   1. tirer x, y au hasard dans [0, 1[  (random.random())
        #   2. si le point est dans le quart de cercle (x*x + y*y <= 1) : dedans += 1
        pass
    # TODO — la proportion vaut pi/4, donc renvoyer 4 * dedans / n
    return 0

print(estimer_pi(100000))   # proche de 3.14
