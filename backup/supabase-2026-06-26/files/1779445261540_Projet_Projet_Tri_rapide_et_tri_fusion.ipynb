# %% [markdown]
# # Tri rapide et tri fusion
#
# **À écrire :** le partage du tri rapide et la fusion.

# %%
def tri_rapide(L):
    if len(L) <= 1:
        return L
    pivot = L[0]
    # TODO — diviser pour régner :
    #   1. petits = éléments de L[1:] strictement < pivot
    #   2. grands = éléments de L[1:] >= pivot
    #   3. renvoyer tri_rapide(petits) + [pivot] + tri_rapide(grands)
    pass

def fusion(a, b):
    res, i, j = [], 0, 0
    # TODO — fusionner deux listes triées a et b :
    #   1. tant que i < len(a) et j < len(b) : ajouter le plus petit de a[i]/b[j] et avancer son indice
    #   2. renvoyer res + le reste de a + le reste de b
    pass

def tri_fusion(L):
    if len(L) <= 1:
        return L
    m = len(L) // 2
    return fusion(tri_fusion(L[:m]), tri_fusion(L[m:]))

print(tri_rapide([5, 2, 8, 1, 9]))
print(tri_fusion([5, 2, 8, 1, 9]))
