# %% [markdown]
# # Morpion (Tic-Tac-Toe)
#
# **À écrire :** la détection du gagnant.

# %%
def gagnant(g):
    # On rassemble lignes, colonnes et diagonales :
    lignes = [list(l) for l in g]
    lignes += [list(col) for col in zip(*g)]
    lignes.append([g[i][i] for i in range(3)])
    lignes.append([g[i][2 - i] for i in range(3)])
    # TODO — pour chaque l de lignes :
    #   si l[0] n'est pas vide ET l[0] == l[1] == l[2] -> renvoyer l[0]
    # si rien trouvé -> renvoyer None
    pass

g = [[" "] * 3 for _ in range(3)]
g[0][0] = g[1][1] = g[2][2] = "X"
print(gagnant(g))   # X
